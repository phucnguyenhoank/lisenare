# %%
# Out:
# Episode 0: Reward = 1.00
# Episode 1: Reward = 1.00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 11
#       8     reading_embeddings, item_ids = get_all_item_embeddings(session)
#      10 env = ReadingRecEnvContinuous(reading_embeddings)
# ---> 11 trained_q_net = train_dqn_continuous(
#      12     env,
#      13     reading_embeddings,
#      14     state_dim=env.observation_space.shape[0],
#      15     action_dim=env.action_space.shape[0],
#      16 )
#
# Cell In[4], line 62, in train_dqn_continuous(env, reading_embeddings, state_dim, action_dim, K, gamma, lr, batch_size, buffer_size, episodes, target_update)
#      59 q_next = q_next_flat.max(1, keepdim=True)[0]
#      61 y = r_b + gamma * q_next * done_mask
# ---> 62 q_pred = q_net(s_b, a_b)
#      64 loss = nn.MSELoss()(q_pred, y.detach())
#      66 optimizer.zero_grad()
#
# ...
